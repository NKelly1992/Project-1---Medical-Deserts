# %%
import requests
import json
import csv
import numpy as np
import pandas as pd

#Set up URL and API call
base_url = "https://npiregistry.cms.hhs.gov/api/?version=2.1"
# params1 = {"state": "IL", "taxonomy_description": "Community/Retail Pharmacy"}
taxonomy_description = "Community/Retail Pharmacy"
states = ["IL", "IN", "MI", "IA", "MO", "OH", "ND", "SD", "NE", "KS"]

response = requests.get(pharma_query_url).json()
print(len(response['results']))
# Out:
# 200

# %%
# Create list to store data
st=[]
name = []
address = []
city = []
statelist = []
zipcode = []

counter = 0

# %%
for state in states:
    pharmaName = []
    pharmaAddress = []
    pharmaCity = []
    pharmaState = []
    pharmaZip = []
    pharma_query_url = f'{base_url}&state={state}&taxonomy_description={taxonomy_description}&limit=200'
    response = requests.get(pharma_query_url).json()
    res = response['results']
    st.append(res)
    for i in range(len(res)):
        x = res[i]
        pharmaName.append(x['basic']['name'])
        pharmaAddress.append(x["addresses"][0]["address_1"])
        pharmaCity.append(x["addresses"][0]["city"])
        pharmaState.append(x["addresses"][0]["state"])
        pharmaZip.append(x["addresses"][0]["postal_code"])
    name.append(pharmaName)
    address.append(pharmaAddress)
    city.append(pharmaCity)
    statelist.append(pharmaState)
    zipcode.append(pharmaZip)

        #counter += 1
       # print(f'Processing Record {counter} of {state}')
    #except KeyError:
        #print('Missing data, move on to next')

# %%
mi_pharma_df = pd.DataFrame({
    "Name": name[2],
    "Address": address[2],
    "City": city[2],
    "State": statelist[2],
    "Zip Code": zipcode[2]
})

# %%
in_pharma_df = pd.DataFrame({
    "Name": name[1],
    "Address": address[1],
    "City": city[1],
    "State": statelist[1],
    "Zip Code": zipcode[1]
})

# %%
il_pharma_df= pd.DataFrame({
    "Name": name[0],
    "Address": address[0],
    "City": city[0],
    "State": statelist[0],
    "Zip Code": zipcode[0]
})

# %%
il_pharma_df = il_pharma_df.loc[(il_pharma_df["State"]=="IL") | (il_pharma_df["State"]=="")]
il_pharma_df.head(15)
# Out:
#                             Name                  Address              City  \
# 0       TELESCRIPT PHARMACY INC.       3535 E NEW YORK ST            AURORA
# 1   INTERDEPENDENT PHARMACY, LLC        404 N SEYMOUR AVE         MUNDELEIN
# 2       NASHVILLE PHARMACY, INC.           154 E ADAMS ST         NASHVILLE
# 3                    WALGREEN CO          7410 N CLARK ST           CHICAGO
# 4            CHMIELESKI COURTNEY         3400 LINCOLN HWY    OLYMPIA FIELDS
# 5          GENOA HEALTHCARE, LLC     3348 W 87TH ST STE P           CHICAGO
# 7        BIOSCRIP PHARMACY, INC.        912 W BELMONT AVE           CHICAGO
# 9      DECATUR MEMORIAL HOSPITAL         2300 N EDWARD ST           DECATUR
# 10       ERNEST & SUSAN L ROALES            208 N MAIN ST        BRIDGEPORT
# 13             OMAR PHARMACY INC       4613 N SHERIDAN RD           CHICAGO
# 16        MEDICATE PHARMACY, INC             100 N 8TH ST  EAST SAINT LOUIS
# 17        LIFELINE PHARMACY, INC      455 E MAIN ST STE 4       EAST DUNDEE
# 19      MOORE FAMILY STORES INC.          202 W EDGAR AVE             CASEY
# 26         AMERICAN PHARMACY INC      2200 W ROOSEVELT RD         BROADVIEW
# 27              200 PHARMACY INC  9133 S STONY ISLAND AVE           CHICAGO
#
#    State   Zip Code
# 0     IL  605044465
# 1     IL  600601835
# 2     IL  622631863
# 3     IL  606261620
# 4     IL  604611703
# 5     IL  606523767
# 7     IL  606576466
# 9     IL  625264163
# 10    IL  624171522
# 13    IL  606405019
# 16    IL  622012989
# 17    IL  601181523
# 19    IL  624201024
# 26    IL  601553888
# 27    IL  606173512
