# %%
#Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
from matplotlib.pyplot import figure

import requests
import json
from api_keys import g_key
import gmaps

# %%
income_data=pd.read_csv("median_income.csv")

# %%
income_data.head()
# Out:
#            GEO_ID                     NAME               S1901_C01_001E  \
# 0              id     Geographic Area Name  Estimate!!Households!!Total
# 1  0500000US01003  Baldwin County, Alabama                        82325
# 2  0500000US01015  Calhoun County, Alabama                        44636
# 3  0500000US01043  Cullman County, Alabama                        32090
# 4  0500000US01049   DeKalb County, Alabama                        24880
#
#                        S1901_C01_001M  \
# 0  Margin of Error!!Households!!Total
# 1                                3231
# 2                                2010
# 3                                1233
# 4                                1347
#
#                                    S1901_C01_002E  \
# 0  Estimate!!Households!!Total!!Less than $10,000
# 1                                             4.9
# 2                                             9.6
# 3                                             4.4
# 4                                             7.2
#
#                                       S1901_C01_002M  \
# 0  Margin of Error!!Households!!Total!!Less than ...
# 1                                                1.6
# 2                                                3.1
# 3                                                1.5
# 4                                                2.8
#
#                                     S1901_C01_003E  \
# 0  Estimate!!Households!!Total!!$10,000 to $14,999
# 1                                              3.9
# 2                                              7.3
# 3                                              5.4
# 4                                              8.4
#
#                                       S1901_C01_003M  \
# 0  Margin of Error!!Households!!Total!!$10,000 to...
# 1                                                1.4
# 2                                                2.4
# 3                                                2.2
# 4                                                3.8
#
#                                     S1901_C01_004E  \
# 0  Estimate!!Households!!Total!!$15,000 to $24,999
# 1                                              9.4
# 2                                              8.4
# 3                                             11.0
# 4                                             15.6
#
#                                       S1901_C01_004M  ...  \
# 0  Margin of Error!!Households!!Total!!$15,000 to...  ...
# 1                                                2.0  ...
# 2                                                2.0  ...
# 3                                                2.8  ...
# 4                                                3.5  ...
#
#                                       S1901_C04_012E  \
# 0  Estimate!!Nonfamily households!!Median income ...
# 1                                              37494
# 2                                              26143
# 3                                              22464
# 4                                              21213
#
#                                       S1901_C04_012M  \
# 0  Margin of Error!!Nonfamily households!!Median ...
# 1                                               5940
# 2                                               3350
# 3                                               3132
# 4                                               4028
#
#                                       S1901_C04_013E  \
# 0  Estimate!!Nonfamily households!!Mean income (d...
# 1                                              48871
# 2                                              32609
# 3                                              28508
# 4                                              36416
#
#                                       S1901_C04_013M  \
# 0  Margin of Error!!Nonfamily households!!Mean in...
# 1                                               5729
# 2                                               4229
# 3                                               2622
# 4                                              10258
#
#                                       S1901_C04_014E  \
# 0  Estimate!!Nonfamily households!!PERCENT ALLOCA...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       S1901_C04_014M  \
# 0  Margin of Error!!Nonfamily households!!PERCENT...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       S1901_C04_015E  \
# 0  Estimate!!Nonfamily households!!PERCENT ALLOCA...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       S1901_C04_015M  \
# 0  Margin of Error!!Nonfamily households!!PERCENT...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       S1901_C04_016E  \
# 0  Estimate!!Nonfamily households!!PERCENT ALLOCA...
# 1                                               30.1
# 2                                               35.7
# 3                                               37.1
# 4                                               36.0
#
#                                       S1901_C04_016M
# 0  Margin of Error!!Nonfamily households!!PERCENT...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
# [5 rows x 130 columns]

# %%
inc_df=income_data[["NAME","S1901_C01_012E"]]

# %%
inc_df.head()
# Out:
#                       NAME                                 S1901_C01_012E
# 0     Geographic Area Name  Estimate!!Households!!Median income (dollars)
# 1  Baldwin County, Alabama                                          56439
# 2  Calhoun County, Alabama                                          48156
# 3  Cullman County, Alabama                                          50906
# 4   DeKalb County, Alabama                                          44208

# %%
inc_df.drop(0,inplace=True)

# %%
len(inc_df)
# Out:
# 841

# %%
inc_df.head()
# Out:
#                       NAME S1901_C01_012E
# 1  Baldwin County, Alabama          56439
# 2  Calhoun County, Alabama          48156
# 3  Cullman County, Alabama          50906
# 4   DeKalb County, Alabama          44208
# 5   Elmore County, Alabama          61854

# %%
inc_df=inc_df.rename(columns={"NAME": "County", 
                   "S1901_C01_012E": "Median_Income"})

# %%
inc_df.head()
# Out:
#                     County Median_Income
# 1  Baldwin County, Alabama         56439
# 2  Calhoun County, Alabama         48156
# 3  Cullman County, Alabama         50906
# 4   DeKalb County, Alabama         44208
# 5   Elmore County, Alabama         61854

# %%
min(inc_df['Median_Income'].astype(float))
# Out:
# 14525.0

# %%
for index, row in inc_df.iterrows():
    row['County']=row['County']+',USA'

# %%
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
latitudes=[]
longitudes=[]
params = {"key": g_key}
income=[]

for index, row in inc_df.iterrows():
    address=row
    params['address'] = address
    try:
        my_geo = requests.get(base_url, params).json()
        lat = my_geo["results"][0]["geometry"]["location"]["lat"]
        lng = my_geo["results"][0]["geometry"]["location"]["lng"]

        latitudes.append(lat)

        longitudes.append(lng)
        
        income.append(row['Median_Income'])
    except:
        print(f"Error locating address: {address} ")

print("End of Loop")
# Out:
# End of Loop

# %%
income=inc_df['Median_Income'].astype(float)

county_inc=pd.DataFrame({"Lat": latitudes,
                           "Lng" :longitudes,
                         "Income": income
                      })

county_inc.head()
# Out:
#          Lat        Lng   Income
# 1  30.601074 -87.776333  56439.0
# 2  33.770158 -85.807660  48156.0
# 3  34.201154 -86.822034  50906.0
# 4  34.521140 -85.684578  44208.0
# 5  32.564708 -86.012157  61854.0

# %%
county_inc.to_csv("county_inc.csv")

# %%
all_addr=pd.read_csv("all_addr.csv")
all_addr.head()
# Out:
#    Unnamed: 0        Lat        Lng
# 0           0  34.221688 -86.160710
# 1           1  34.441975 -85.755014
# 2           2  33.310670 -85.485005
# 3           3  32.695544 -87.586908
# 4           4  34.720758 -86.574990

# %%
locations=all_addr[['Lat','Lng']]
locs=county_inc[['Lat','Lng']]
weights=county_inc['Income']

figure_layout = {
    'width': '800px',
    'height': '500px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
gmaps.configure(api_key=g_key)
fig = gmaps.figure(layout=figure_layout)
#fig = gmaps.figure()

hosp_layer = gmaps.symbol_layer(
   locations, fill_color='rgba(0, 0, 150, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=2

)

heat_layer = gmaps.heatmap_layer(locs, weights=weights, 
                                 dissipating=False, max_intensity=300000,
                                 point_radius = 1)
fig.add_layer(heat_layer)

fig.add_layer(hosp_layer)
plt.savefig("hospitals_inc.png")
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='500px', margin='0 auto 0 auto', padding='1px', wi…
